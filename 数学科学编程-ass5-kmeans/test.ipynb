# %%
from sklearn.cluster import KMeans
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import KMeans
from matplotlib import pyplot

# %% [markdown]
# 定义数据集

# %%
x, _ = make_classification(n_samples=1000,n_features=2,n_informative=2,n_redundant=0,random_state=4)

# %% [markdown]
# 定义模型

# %%
model = KMeans(n_clusters=2)

# %% [markdown]
# 模型拟合

# %%
model.fit(x)
# Out:
# KMeans(n_clusters=2)

# %% [markdown]
# 为每个示例分配一个集群

# %%
yhat = model.predict(x)

# %% [markdown]
# 检索唯一集群

# %%
clusters = unique(yhat)

# %% [markdown]
# 为每个集群样本创建散点图

# %%
for cluster in clusters:
    #获取此群集的示例的行索引
    row_ix = where(yhat == cluster)
    #创建这些样本的散布
    pyplot.scatter(x[row_ix,0],x[row_ix,1])
    #绘制散点图
    pyplot.show()

# %%
x#1000个样本，2个特征，2类
# Out:
# array([[ 1.00199419,  0.65413484],
#        [ 0.77511939,  1.51405693],
#        [ 1.05948057, -0.92286793],
#        ...,
#        [ 1.48332175, -0.09749996],
#        [ 0.73511474, -0.81884743],
#        [ 0.75714166,  0.49474281]])

# %%
pyplot.scatter(x[:,0],x[:,1],c=yhat)

# %% [markdown]
# 最后我们得到了两幅图，它们是样本的散度，一个被分到了0一个被分到了1，1类的散布和0类的散布如上（数据）

# %%
yhat.shape
# Out:
# (1000,)

# %%
clusters
# Out:
# array([0, 1])

# %%
x.shape
# Out:
# (1000, 2)

# %%
type(x)
# Out:
# numpy.ndarray
